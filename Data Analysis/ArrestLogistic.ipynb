# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
import csv
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame

df= pd.read_csv(r'C:\Users\dkrenn\Desktop\GW-Bootcamp-Final-Project\Data Analysis\Resources\cleaned_data.csv')
df.head()
# Out:
#    Unnamed: 0         ID   AreaName  VicAge VicSex      VicRace StatusCode  \
# 0           0  190326475   Wilshire     999      M  Multiracial         AA
# 1           1  200106753    Central      47      M  Multiracial         IC
# 2           2  200320258  Southwest      19    NaN                      IC
# 3           3  200907217   Van Nuys      19      M  Multiracial         IC
# 4           4  220614831  Hollywood      28      M     Hispanic         IC
#
#        Lat       Lon CrimeType     AgeGroup   AddressType Arrest
# 0  34.0375 -118.3506     Theft      Unknown  Public Space    Yes
# 1  34.0444 -118.2628     Theft        40-54  Public Space     No
# 2  34.0210 -118.3002     Theft  Young Adult   Residential     No
# 3  34.1576 -118.4387     Theft  Young Adult      Buisness     No
# 4  34.0944 -118.3277     Theft        25-39  Public Space     No

# %%
# Remove Unneeded Columns
df= df.drop(columns =["Unnamed: 0", "ID", "StatusCode", "Lat", "Lon", "AgeGroup"])
df.head()
# Out:
#     AreaName  VicAge VicSex      VicRace CrimeType   AddressType Arrest
# 0   Wilshire     999      M  Multiracial     Theft  Public Space    Yes
# 1    Central      47      M  Multiracial     Theft  Public Space     No
# 2  Southwest      19    NaN                  Theft   Residential     No
# 3   Van Nuys      19      M  Multiracial     Theft      Buisness     No
# 4  Hollywood      28      M     Hispanic     Theft  Public Space     No

# %%
# Remove Missing Age Codes
df=df.loc[df["VicAge"]<999]

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = df['Arrest']

# %%
# Separate the X variable, the features
x = df.drop(columns='Arrest')
x = pd.get_dummies(x, dtype=int)
x.head()
# Out:
#    VicAge  AreaName_77th Street  AreaName_Central  AreaName_Devonshire  \
# 1      47                     0                 1                    0
# 2      19                     0                 0                    0
# 3      19                     0                 0                    0
# 4      28                     0                 0                    0
# 5      41                     0                 0                    0
#
#    AreaName_Foothill  AreaName_Harbor  AreaName_Hollenbeck  \
# 1                  0                0                    0
# 2                  0                0                    0
# 3                  0                0                    0
# 4                  0                0                    0
# 5                  0                0                    0
#
#    AreaName_Hollywood  AreaName_Mission  AreaName_N Hollywood  ...  \
# 1                   0                 0                     0  ...
# 2                   0                 0                     0  ...
# 3                   0                 0                     0  ...
# 4                   1                 0                     0  ...
# 5                   0                 0                     0  ...
#
#    CrimeType_Property Destruct  CrimeType_Robbery  CrimeType_Sex Crime  \
# 1                            0                  0                    0
# 2                            0                  0                    0
# 3                            0                  0                    0
# 4                            0                  0                    0
# 5                            0                  0                    0
#
#    CrimeType_Theft  CrimeType_Weapons  AddressType_Buisness  \
# 1                1                  0                     0
# 2                1                  0                     0
# 3                1                  0                     1
# 4                1                  0                     0
# 5                1                  0                     0
#
#    AddressType_Other  AddressType_Public Space  AddressType_Public Transit  \
# 1                  0                         1                           0
# 2                  0                         0                           0
# 3                  0                         0                           0
# 4                  0                         1                           0
# 5                  0                         0                           0
#
#    AddressType_Residential
# 1                        0
# 2                        1
# 3                        0
# 4                        0
# 5                        1
#
# [5 rows x 47 columns]

# %%
# Review the y variable Series
y[:5]
# Out:
# 1    No
# 2    No
# 3    No
# 4    No
# 5    No
# Name: Arrest, dtype: object

# %%
# Review the X variable DataFrame
x[:5]
# Out:
#    VicAge  AreaName_77th Street  AreaName_Central  AreaName_Devonshire  \
# 1      47                     0                 1                    0
# 2      19                     0                 0                    0
# 3      19                     0                 0                    0
# 4      28                     0                 0                    0
# 5      41                     0                 0                    0
#
#    AreaName_Foothill  AreaName_Harbor  AreaName_Hollenbeck  \
# 1                  0                0                    0
# 2                  0                0                    0
# 3                  0                0                    0
# 4                  0                0                    0
# 5                  0                0                    0
#
#    AreaName_Hollywood  AreaName_Mission  AreaName_N Hollywood  ...  \
# 1                   0                 0                     0  ...
# 2                   0                 0                     0  ...
# 3                   0                 0                     0  ...
# 4                   1                 0                     0  ...
# 5                   0                 0                     0  ...
#
#    CrimeType_Property Destruct  CrimeType_Robbery  CrimeType_Sex Crime  \
# 1                            0                  0                    0
# 2                            0                  0                    0
# 3                            0                  0                    0
# 4                            0                  0                    0
# 5                            0                  0                    0
#
#    CrimeType_Theft  CrimeType_Weapons  AddressType_Buisness  \
# 1                1                  0                     0
# 2                1                  0                     0
# 3                1                  0                     1
# 4                1                  0                     0
# 5                1                  0                     0
#
#    AddressType_Other  AddressType_Public Space  AddressType_Public Transit  \
# 1                  0                         1                           0
# 2                  0                         0                           0
# 3                  0                         0                           0
# 4                  0                         1                           0
# 5                  0                         0                           0
#
#    AddressType_Residential
# 1                        0
# 2                        1
# 3                        0
# 4                        0
# 5                        1
#
# [5 rows x 47 columns]

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
classifier = LogisticRegression(solver='lbfgs', random_state=1)

# Fit the model using training data
classifier.fit(x_train, y_train)
# Out:
# C:\Users\dkrenn\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=1)

# %%
# Make a prediction using the testing data
predictions = classifier.predict(x_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#        Prediction Actual
# 332823         No    Yes
# 525863         No     No
# 846642         No     No
# 33785          No     No
# 845110         No     No
# ...           ...    ...
# 449274         No     No
# 272041         No     No
# 423714         No     No
# 351815         No     No
# 625059         No     No
#
# [165636 rows x 2 columns]

# %%
# Print the balanced_accuracy score of the model
balanced_accuracy_score(y_test, predictions)
# Out:
# 0.5011262161167216

# %%
# Generate a confusion matrix for the model
confuse_matrix = confusion_matrix(y_test, predictions)

# %%
# Print the classification report for the model
class_report = classification_report(y_test, predictions)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.91      1.00      0.95    150140
#          Yes       0.56      0.00      0.00     15496
#
#     accuracy                           0.91    165636
#    macro avg       0.73      0.50      0.48    165636
# weighted avg       0.87      0.91      0.86    165636

# %%
# USE RESAMPLED DATA
# Import the RandomOverSampler module form imbalanced-learn
from imblearn.over_sampling import RandomOverSampler

# # Assign a random_state parameter of 1 to the model
ros_model = RandomOverSampler(random_state=1)

# Fit the original training data to the random_oversampler model
x_resampled, y_resampled = ros_model.fit_resample(x_train, y_train)

# %%
# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
classifier2 = LogisticRegression(solver='lbfgs', random_state=1)

# Fit the model using training data
classifier2.fit(x_resampled, y_resampled)

# Make a prediction using the testing data
predictions2 = classifier2.predict(x_test)
pd.DataFrame({"Prediction": predictions2, "Actual": y_test})
# Out:
# C:\Users\dkrenn\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#        Prediction Actual
# 332823        Yes    Yes
# 525863        Yes     No
# 846642        Yes     No
# 33785         Yes     No
# 845110         No     No
# ...           ...    ...
# 449274        Yes     No
# 272041         No     No
# 423714        Yes     No
# 351815         No     No
# 625059         No     No
#
# [165636 rows x 2 columns]

# %%
balanced_accuracy_score(y_test, predictions2)
# Out:
# 0.6802754746060793

# %%
# Generate a confusion matrix for the model
confuse_matrix = confusion_matrix(y_test, predictions2)

# %%
# Print the classification report for the model
class_report2 = classification_report(y_test, predictions2)
print(class_report2)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.96      0.62      0.76    150140
#          Yes       0.17      0.74      0.27     15496
#
#     accuracy                           0.64    165636
#    macro avg       0.56      0.68      0.52    165636
# weighted avg       0.88      0.64      0.71    165636
